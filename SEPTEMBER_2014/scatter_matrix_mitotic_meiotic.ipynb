# %%
#pwd

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
# %matplotlib inline
#http://nbviewer.ipython.org/github/ipython/ipython/blob/1.x/examples/notebooks/Part%203%20-%20Plotting%20with%20Matplotlib.ipynb

from pandas.tools.plotting import scatter_matrix

# %%
df_meiotic_true=pd.read_csv('meiotic_true.csv')

# %%
df_meiotic_true.head()
# Out:
#    aster-to-pole_distance_2_um  astere-to-pole_distance_1_um  \
# 0                            0                             0
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                            0                             0
# 4                          NaN                           NaN
#
#    cell_diameter_um  centrosome  chromosomes classification  \
# 0         235.36122           1           36             bd
# 1         262.71236           1           36             bd
# 2         258.72700           1           36             bd
# 3         221.38032           1           36             bd
# 4         227.39050           1           36             bd
#
#    classification_CAT cleavage_type  cleavage_type_CAT day_old   ...    \
# 0                   1           rah                  1  131106   ...
# 1                   1           rah                  1  131106   ...
# ...

# %%
df_meiotic_true.shape
# Out:
# (473, 40)

# %%
473*40
# Out:
# 18920

# %%
np.sum(np.sum(df_meiotic_true.isnull()))
# Out:
# 1568

# %%
473*40/(np.sum(np.sum(df_meiotic_true.isnull()))) #12% empty cells
# Out:
# 12

# %%
df_original=pd.read_csv('original.csv')

# %%
df_original.head()
# Out:
#    time_pf num_of_cells  meiotic stage  cell_diameter_um  \
# 0      210            1        0     a         177.82149
# 1      210            1        0     m         163.05828
# 2      210            1        0     p         206.00580
# 3      210            1        0     m         194.04000
# 4      210            1        0   NaN         180.36018
#
#    spindle_length__asters_um  spindle_length_poles_um  spindle_width_um  \
# 0                   41.37903                 26.13072          14.45598
# 1                   24.85329                 18.28827           9.97689
# 2                   35.08890                 27.24645          14.63385
# 3                   42.39774                 42.39774          17.46360
# 4                        NaN                      NaN               NaN
#
#    spindle_aspect_ratio_asters_um  spindle_aspect_ratio_poles_um  \
# 0                        2.862416                       1.807606
# ...

# %%
df_meiotic_false = pd.read_csv('meiotic_false.csv')

# %%
df_meiotic_false.head()
# Out:
#    aster-to-pole_distance_2_um  astere-to-pole_distance_1_um  \
# 0                       2.9106                        2.5872
# 1                       0.0000                        0.0000
# 2                       0.0000                        0.0000
# 3                       0.0000                        0.0000
# 4                          NaN                           NaN
#
#    cell_diameter_um  centrosome  chromosomes classification  \
# 0         177.82149           1           36             bd
# 1         163.05828           1           36             bd
# 2         206.00580           1           36             bd
# 3         194.04000           1           36             bd
# 4         180.36018           1           36             bd
#
#    classification_CAT cleavage_type  cleavage_type_CAT day_old   ...    \
# 0                   1           rah                  1  131106   ...
# 1                   1           rah                  1  131106   ...
# ...

# %%
df_meiotic_false.describe()
# Out:
#        aster-to-pole_distance_2_um  astere-to-pole_distance_1_um  \
# count                  1370.000000                   1395.000000
# mean                      1.444982                      1.543719
# std                       2.939563                      2.697953
# min                       0.000000                      0.000000
# 25%                       0.000000                      0.000000
# 50%                       0.000000                      0.000000
# 75%                       2.240138                      2.457840
# max                      39.800000                     28.000000
#
#        cell_diameter_um  centrosome  chromosomes  classification_CAT  \
# count       1445.000000        1456  1456.000000         1456.000000
# mean          90.495206           1    30.206044            1.717720
# std          119.231766           0    10.845817            0.918307
# min            0.100000           1     8.000000            1.000000
# ...

# %%
(df_meiotic_false.shape[0]*df_meiotic_false.shape[1])/np.sum(np.sum(df_meiotic_false.isnull())) #19% empty cells
# Out:
# 19

# %%
scat_meiotic_T = scatter_matrix(df_meiotic_true, figsize = (70,70), diagonal = 'kde')
#plt.savefig('scatter_matrix_meiotic_complete_numeric.eps')

# %%
scat_meiotic_T = scatter_matrix(df_meiotic_false, figsize = (70,70), diagonal = 'kde')
#plt.savefig('scatter_matrix_mitotic_complete_numeric.eps')
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.py:2544: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1.0, right=1.0
#   'left=%s, right=%s') % (left, right))
# /usr/local/lib/python2.7/site-packages/matplotlib/axes/_base.py:2791: UserWarning: Attempting to set identical bottom==top results
# in singular transformations; automatically expanding.
# bottom=1.0, top=1.0
#   'bottom=%s, top=%s') % (bottom, top))
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-39-a93809a3313f> in <module>()
# ----> 1 scat_meiotic_T = scatter_matrix(df_meiotic_false, figsize = (70,70), diagonal = 'kde')
#       2 plt.savefig('scatter_matrix_mitotic_complete_numeric.eps')
#       3
#
# ...

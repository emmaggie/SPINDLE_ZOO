# %% [markdown]
# #MARINA::SPINDLE ZOO II
# This is an updated version of analysis for Marina. For the previous version check:
# **/Volumes/Magdalena_NEW1/MARINA_PAPER/AUGUST_2014/Marina_spindle_zoo.ipynb**. Marina is doing all the regular plots. This is suppossed to tackle the multivariate analysis.
# New version started on 09172014.
#
# Plan:
# 1. Plot all (matrix): (pandas or R)
# 2. Cluster (k-means and hierarchical)
# 3. Run logistic regression (AUC curve)
# 4. Run decision tree
# 5. Run PCA & LDA (R & scikit-learn)

# %% [markdown]
# *Will try to use **R inline**. Following instructions: [here](http://nbviewer.ipython.org/github/ipython/ipython/blob/3607712653c66d63e0d7f13f073bde8c0f209ba8/docs/examples/notebooks/rmagic_extension.ipynb) and [here](http://nbviewer.ipython.org/github/fperez/nipy-notebooks/blob/master/exploring_r_formula.ipynb). The main resource is located [here](http://nbviewer.ipython.org/).
# There is also a partial support for R in pandas: [still in beta](http://pandas.pydata.org/pandas-docs/stable/r_interface.html)*
#
# *Some [Julia](https://github.com/JuliaLang/IJulia.jl). Julia is on Homebrew, but you can us dmg from [here](http://julialang.org/downloads/). When using Hombrew [use this formula](https://github.com/staticfloat/homebrew-julia). If you hit installation issue, use [this solution](https://github.com/staticfloat/homebrew-julia/issues/110). [Julia's docs](http://docs.julialang.org/en/release-0.3/manual/getting-started/). Test installation with **brew test -v julia**. You can also run: **/usr/local/Cellar/julia/0.3.0/bin/julia -e "Base.runtests()".***

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
# %matplotlib inline
#http://nbviewer.ipython.org/github/ipython/ipython/blob/1.x/examples/notebooks/Part%203%20-%20Plotting%20with%20Matplotlib.ipynb
import pygal
from IPython.display import SVG

#you will need recsys, scikitlearn, statmodels

# %%
print pd.__version__
print np.__version__
#print matplotlib.__version__
print pygal.__version__
#print IPython.display.__version__
# Out:
# 0.14.0
# 1.8.1
# 1.4.6

# %% [markdown]
# ##STEP1: LOAD DATA
# Relevant file: **ZOODATA_140916.xlsx**

# %%
# !ls ../
# Out:
# AUGUST_2014                SEPTEMBER_2014             ZOODATA_140916.xlsx
# Data_Averages.xlsx         Spindle Zoo_column key.txt ZOODATA_140923.xlsx

# %% [markdown]
# DF is the original data frame. There will be several copies of it along the way. I like keeping the original seperate.

# %%
df=pd.read_excel('../ZOODATA_140923.xlsx')

# %%
df.head()
# Out:
#      date                   image objective  time PF # of cells meiotic stage  \
# 0  131106   131106batstar_35hpf 5       40x  210 min          1       f     a
# 1  131106   131106batstar_35hpf 6       40x  210 min          1       f     m
# 2  131106   131106batstar_35hpf 7       40x  210 min          1       f     p
# 3  131106  131106batstar_35hpf 10       40x  210 min          1       f     m
# 4  131106  131106batstar_35hpf 11       40x  210 min          1       f    na
#
#   cell diameter (um) Spindle Length_ asters (um) Spindle length_poles (um)  \
# 0           177.8215                    41.37903                  26.13072
# 1           163.0583                    24.85329                  18.28827
# 2           206.0058                     35.0889                  27.24645
# 3             194.04                    42.39774                  42.39774
# 4           180.3602                          na                        na
#
#              ...            Distance between chromosomes (um) microscope  \
# 0            ...                                     10.55901       mm40
# 1            ...                                            0       mm40
# 2            ...                                           na       mm40
# 3            ...                                            0       mm40
# 4            ...                                           na       mm40
#
#   fixation          organism         phylum classification genome chromosomes  \
# 0       pf  asterina miniata  echinodermata             bd    811          36
# 1       pf  asterina miniata  echinodermata             bd    811          36
# 2       pf  asterina miniata  echinodermata             bd    811          36
# 3       pf  asterina miniata  echinodermata             bd    811          36
# 4       pf  asterina miniata  echinodermata             bd    811          36
#
#       Day cleavage type
# 0  131106            ra
# 1  131106            ra
# 2  131106            ra
# 3  131106            ra
# 4  131106            ra
#
# [5 rows x 35 columns]

# %%
df.shape
# Out:
# (1929, 35)

# %%
df.tail()
# Out:
#         date                                image objective time PF  \
# 1924  130308  20x Slide 4.I_w1Confocal Rho_s1.STK       20x     180
# 1925  130308  20x Slide 4.I_w1Confocal Rho_s4.STK       20x     180
# 1926  130308  20x Slide 3.I_w1Confocal Rho_s1.STK       20x     130
# 1927  130308  20x Slide 3.I_w1Confocal Rho_s3.STK       20x     130
# 1928  130308  20x Slide 3.I_w1Confocal Rho_s7.STK       20x     130
#
#      # of cells meiotic stage cell diameter (um) Spindle Length_ asters (um)  \
# 1924          8       f     m           492.7488                     82.9952
# 1925          8       f     m            625.152                     86.6304
# 1926          4       f     m           1034.342                     68.1984
# 1927          4       f     m           1486.643                     75.5712
# 1928          4       f     m           1455.718                      68.096
#
#      Spindle length_poles (um)            ...             \
# 1924                   50.3808            ...
# 1925                   62.0544            ...
# 1926                   49.7664            ...
# 1927                   48.3328            ...
# 1928                   47.0016            ...
#
#      Distance between chromosomes (um) microscope fixation        organism  \
# 1924                                 0      zax20        m  xenopus laevis
# 1925                                 0      zax20        m  xenopus laevis
# 1926                                 0      zax20        m  xenopus laevis
# 1927                                 0      zax20        m  xenopus laevis
# 1928                                 0      zax20        m  xenopus laevis
#
#         phylum classification genome chromosomes     Day cleavage type
# 1924  Chordata             bd   3100          36  121102           dra
# 1925  Chordata             bd   3100          36  121102           dra
# 1926  Chordata             bd   3100          36  121102           dra
# 1927  Chordata             bd   3100          36  121102           dra
# 1928  Chordata             bd   3100          36  121102           dra
#
# [5 rows x 35 columns]

# %% [markdown]
# ##STEP2: CLEAN UP THE DATA FRAME
#
# This will involve:
# * cleaning up the headers
# * dealing with NaN's
# * cleaning up the values
# * try imputing the missing values (random sampling, median or SVD); compare distributions with and without

# %% [markdown]
# ###Headers:
# Get rid of spaces, brackets, hashes; convert to lower case.

# %%
df.columns #spaces, brackets
# Out:
# Index([u'date', u'image', u'objective', u'time PF', u'# of cells', u'meiotic', u'stage', u'cell diameter (um)', u'Spindle Length_ asters (um)', u'Spindle length_poles (um)', u'spindle width (um)', u'spindle aspect ratio_asters (um)', u'spindle aspect ratio_poles (um)', u'astere-to-pole distance 1 (um)', u'aster-to-pole distance 2 (um)', u'inner aster diameter 1 (um)', u'inner aster diameter 2 (um)', u'outer aster diameter 1 (um)', u'outer  diameter 2 (um)', u'centrosome', u'metaphase plate lengt h (um)', u'metaphase plate width (um)', u'metaphase plate aspect ratio (um)', u'polar body diameter 1 (um)', u'polar body diameter 2 (um)', u'Distance between chromosomes (um)', u'microscope', u'fixation', u'organism', u'phylum', u'classification', u'genome', u'chromosomes', u'Day', u'cleavage type'], dtype='object')

# %%
type(df.columns)
# Out:
# pandas.core.index.Index

# %%
df2=df.copy() #from now on use the copy of original data frame

# %%
#REF: http://pandas.pydata.org/pandas-docs/stable/missing_data.html?highlight=replace
#[name.replace(' ', '_') for name in df.columns]

# %%
df2.columns=[name.replace(' ','_') for name in df2.columns]
df2.columns=[name.replace('(','') for name in df2.columns]
df2.columns=[name.replace(')','') for name in df2.columns]
df2.columns=[name.replace('#','num') for name in df2.columns]
df2.columns=[name.lower() for name in df2.columns]

# %%
df2.head(1)
# Out:
#      date                  image objective  time_pf num_of_cells meiotic  \
# 0  131106  131106batstar_35hpf 5       40x  210 min            1       f
#
#   stage cell_diameter_um spindle_length__asters_um spindle_length_poles_um  \
# 0     a         177.8215                  41.37903                26.13072
#
#             ...           distance_between_chromosomes_um microscope fixation  \
# 0           ...                                  10.55901       mm40       pf
#
#            organism         phylum classification genome chromosomes     day  \
# 0  asterina miniata  echinodermata             bd    811          36  131106
#
#   cleavage_type
# 0            ra
#
# [1 rows x 35 columns]

# %% [markdown]
# From the variables below, **consider as y**: 'organism' (28), 'meiotic' (if false - mitotic) (5), 'centrosome' (9)

# %%
l=list(df2.columns)
print l.index('organism'), l.index('meiotic'), l.index('centrosome')
# Out:
# 28 5 19

# %%
df2.columns
# Out:
# Index([u'date', u'image', u'objective', u'time_pf', u'num_of_cells', u'meiotic', u'stage', u'cell_diameter_um', u'spindle_length__asters_um', u'spindle_length_poles_um', u'spindle_width_um', u'spindle_aspect_ratio_asters_um', u'spindle_aspect_ratio_poles_um', u'astere-to-pole_distance_1_um', u'aster-to-pole_distance_2_um', u'inner_aster_diameter_1_um', u'inner_aster_diameter_2_um', u'outer_aster_diameter_1_um', u'outer__diameter_2_um', u'centrosome', u'metaphase_plate_lengt_h_um', u'metaphase_plate_width_um', u'metaphase_plate_aspect_ratio_um', u'polar_body_diameter_1_um', u'polar_body_diameter_2_um', u'distance_between_chromosomes_um', u'microscope', u'fixation', u'organism', u'phylum', u'classification', u'genome', u'chromosomes', u'day', u'cleavage_type'], dtype='object')

# %% [markdown]
# ###Cleaning up the values
# * convert 'na' to 'NaN'
# * dates
# * strip 'min', 'x', get rid of spaces
# * make sure there are no split categories (dupes)
# * binarize

# %%
df2.centrosome.head()
df2.centrosome.value_counts()
# Out:
# t     1789
# f      121
# na      18
# F        1
# dtype: int64

# %% [markdown]
# ####Convert

# %%
df2=df2.replace('na',np.nan)
#df2.date[df2.date=='na'].value_counts()

# %%
type(df2.date[1744])
# Out:
# numpy.float64

# %% [markdown]
# ####Dates

# %%
df2.date.value_counts()
df2.date.isnull().value_counts()
#df2.describe()
type(df2.date[df2.date.isnull()][1744]),type(np.nan)
k=df2.date[df2.date.isnull()][1744]

# %%
type(float(k ))
k==np.nan
pd.isnull(k)
# Out:
# True

# %%
def time_converter(s):
    '''Takes a 'YYMMDD' representation of a date and converts it to 'YYYY-MM-DD'.
    This can easily be converted to date object with: datetime.datetime.strptime(new_s,'%Y-%m-%d')
    Here: it will be converted to pandas Timestamp (pandas.tslib.Timestamp)
    More: 
    https://docs.python.org/2/library/datetime.html
    http://stackoverflow.com/questions/466345/converting-string-into-datetime
    http://docs.scipy.org/doc/numpy/reference/arrays.datetime.html
    http://pandas.pydata.org/pandas-docs/stable/timeseries.html
    ''' 
    if pd.isnull(s)==False: #this will not do the NaN -> NaT conversion - might need to consider it
        s =  str(int(s))
        new_s = '20'+s[:2]+'-'+s[2:4]+'-'+s[4:]
        new_s = pd.to_datetime(new_s) 
        return new_s

# %%
#http://stackoverflow.com/questions/19798153/difference-between-map-applymap-and-apply-methods-in-pandas
#Summing up, apply works on a row / column basis of a DataFrame, applymap works element-wise on a DataFrame, and map works element-wise on a Series.

df2.date = df2.date.map(time_converter)#[1744]

# %%
df2.head(1)
# Out:
#         date                  image objective  time_pf num_of_cells meiotic  \
# 0 2013-11-06  131106batstar_35hpf 5       40x  210 min            1       f
#
#   stage  cell_diameter_um  spindle_length__asters_um  spindle_length_poles_um  \
# 0     a         177.82149                   41.37903                 26.13072
#
#             ...             distance_between_chromosomes_um  microscope  \
# 0           ...                                    10.55901        mm40
#
#    fixation          organism         phylum  classification  genome  \
# 0        pf  asterina miniata  echinodermata              bd     811
#
#    chromosomes     day cleavage_type
# 0           36  131106            ra
#
# [1 rows x 35 columns]

# %%
df2.date[df2.date.isnull()].head()
# Out:
# 1744   NaT
# 1745   NaT
# 1746   NaT
# 1747   NaT
# 1748   NaT
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# ####Strip spurious characters. Make sure there are no split categories.

# %%
#df2.replace(' ','_')
#df2.objective.replace('x','')
#df2.objective = [value.lower() for value in df2.objective]
df2.objective
df2.objective.value_counts()
# Out:
# 40x           1219
# 20x            209
# 60x            189
# 40x olf         67
# zlsm 40x        54
# 20x zlsm        42
# 40x zlsm        24
# 63x             22
# 40x-zlsm        13
# 40x- zlsm       13
# 40X- zlsm        6
# 40x - zlsm       5
# dtype: int64

# %%
df2.objective=df2.objective.map(lambda x : str(x).replace(' ','-'))
df2.objective.value_counts()
# Out:
# 40x           1219
# 20x            209
# 60x            189
# 40x-olf         67
# nan             66
# zlsm-40x        54
# 20x-zlsm        42
# 40x-zlsm        37
# 63x             22
# 40x--zlsm       13
# 40X--zlsm        6
# 40x---zlsm       5
# dtype: int64

# %%
df2.objective=df2.objective.map(lambda x : str(x).replace('---','--'))
df2.objective.value_counts()
# Out:
# 40x          1219
# 20x           209
# 60x           189
# 40x-olf        67
# nan            66
# zlsm-40x       54
# 20x-zlsm       42
# 40x-zlsm       37
# 63x            22
# 40x--zlsm      18
# 40X--zlsm       6
# dtype: int64

# %%
df2.objective=df2.objective.map(lambda x : str(x).replace('--','-'))
df2.objective.value_counts()
# Out:
# 40x         1219
# 20x          209
# 60x          189
# 40x-olf       67
# nan           66
# 40x-zlsm      55
# zlsm-40x      54
# 20x-zlsm      42
# 63x           22
# 40X-zlsm       6
# dtype: int64

# %%
df2.objective=df2.objective.map(lambda x : str(x).replace('zlsm-40x','40x-zlsm'))
df2.objective.value_counts()
# Out:
# 40x         1219
# 20x          209
# 60x          189
# 40x-zlsm     109
# 40x-olf       67
# nan           66
# 20x-zlsm      42
# 63x           22
# 40X-zlsm       6
# dtype: int64

# %%
df2.objective=df2.objective.map(lambda x : str(x).replace('40X-zlsm','40x-zlsm'))
df2.objective.value_counts()
# Out:
# 40x         1219
# 20x          209
# 60x          189
# 40x-zlsm     115
# 40x-olf       67
# nan           66
# 20x-zlsm      42
# 63x           22
# dtype: int64

# %%
df2.head(1)
# Out:
#         date                  image objective  time_pf num_of_cells meiotic  \
# 0 2013-11-06  131106batstar_35hpf 5       40x  210 min            1       f
#
#   stage  cell_diameter_um  spindle_length__asters_um  spindle_length_poles_um  \
# 0     a         177.82149                   41.37903                 26.13072
#
#             ...             distance_between_chromosomes_um  microscope  \
# 0           ...                                    10.55901        mm40
#
#    fixation          organism         phylum  classification  genome  \
# 0        pf  asterina miniata  echinodermata              bd     811
#
#    chromosomes     day cleavage_type
# 0           36  131106            ra
#
# [1 rows x 35 columns]

# %%
df2.time_pf.value_counts()
# Out:
# 0          191
# 210 min    121
# 120 min     79
# 180 min     65
# 300 min     63
# 270 min     60
# 150 min     54
# 20 min      48
# 240 min     47
# 300         44
# 450 min     42
# 180         41
# 120         41
# 40 min      36
# 90 min      31
# 45 min      30
# 30          27
# 30 min      25
# 90          21
# 1200        20
# 25 min      20
# 380         18
# 390         17
# 260         16
# 60          16
# 85 min      15
# 20          15
# 50 min      15
# 210         14
# 330         13
# 150         12
# 140 min     12
# 720          9
# 420          9
# 510          8
# 450          8
# 270          7
# 260 min      6
# 130          5
# 390 min      3
# 65           2
# 135 min      2
# 75           1
# 46 min       1
# dtype: int64

# %%
df2.time_pf=df2.time_pf.map(lambda x : str(x).replace('min',''))
df2.time_pf.value_counts()
# Out:
# nan     599
# 0       191
# 210     121
# 120      79
# 180      65
# 300      63
# 270      60
# 150      54
# 20       48
# 240      47
# 300      44
# 450      42
# 180      41
# 120      41
# 40       36
# 90       31
# 45       30
# 30       27
# 30       25
# 90       21
# 1200     20
# 25       20
# 380      18
# 390      17
# 60       16
# 260      16
# 85       15
# 50       15
# 20       15
# 210      14
# 330      13
# 150      12
# 140      12
# 420       9
# 720       9
# 450       8
# 510       8
# 270       7
# 260       6
# 130       5
# 390       3
# 65        2
# 135       2
# 46        1
# 75        1
# dtype: int64

# %%
df2.head(1)
# Out:
#         date                  image objective time_pf num_of_cells meiotic  \
# 0 2013-11-06  131106batstar_35hpf 5       40x    210             1       f
#
#   stage  cell_diameter_um  spindle_length__asters_um  spindle_length_poles_um  \
# 0     a         177.82149                   41.37903                 26.13072
#
#             ...             distance_between_chromosomes_um  microscope  \
# 0           ...                                    10.55901        mm40
#
#    fixation          organism         phylum  classification  genome  \
# 0        pf  asterina miniata  echinodermata              bd     811
#
#    chromosomes     day cleavage_type
# 0           36  131106            ra
#
# [1 rows x 35 columns]

# %%
df2.num_of_cells.unique() #this is more a description of state
# Out:
# array([1, 2, 4, 8, 16, 26, 12, 64, 128, 32, u'32+', u'64+', 28, nan, 48], dtype=object)

# %%
df2.num_of_cells.value_counts()
# Out:
# 1      691
# 2      239
# 4      232
# 8      190
# 32     148
# 16     139
# 64      76
# 64+     57
# 128     20
# 28      18
# 26      13
# 48      11
# 12       5
# 32+      3
# dtype: int64

# %%
df2.columns
df2.centrosome.value_counts()
df2.centrosome=df2.centrosome.map(lambda x : str(x).replace('F','f'))
df2.centrosome.value_counts()
# Out:
# t      1789
# f       122
# nan      18
# dtype: int64

# %%
df2.day = df2.day.map(time_converter)#[1744]

# %%
df2.phylum = df2.phylum.str.replace('Chordata','chordata')

# %%
[(column,df2[column].value_counts()) for column in df2.columns] #centrosomes: DONE; microscopes #Phyla
# Out:
# [(u'date', 2014-06-03    590
#   2013-12-04    159
#   2013-05-23    143
#   2013-11-25    115
#   2014-03-24    108
#   2014-01-10    103
#   2013-03-08     94
#   NaT            66
#   2010-04-23     65
#   2013-11-18     63
#   2014-02-06     55
#   2014-04-25     55
#   2014-06-17     52
#   2013-11-21     46
#   2013-11-06     34
#   2013-11-22     32
#   2012-11-02     24
#   2014-04-22     22
#   2014-07-18     20
#   2014-06-04     17
#   2014-01-27     11
#   2014-04-04      9
#   2014-03-07      9
#   2014-03-21      7
#   2014-04-24      7
#   2014-02-28      7
#   2014-03-17      6
#   2013-11-12      6
#   2010-05-22      2
#   2012-10-03      1
#   2014-01-24      1
#   dtype: int64), (u'image', 131121_urchinUrchin_2hrPF 6     18
#   131121_urchinUrchin_2hrPF 3     15
#   mus musculus3                   13
#   131125_urchinUrchin 27          12
#   131125_urchinUrchin 26          11
#   spurp_t420mPF                    9
#   131121_urchinUrchin_2hrPF 4      9
#   131118_eleganselegans 35         8
#   spurp_t90m_9_w1Confocal 561      8
#   spurp_t90m_15_w1Confocal 561     8
#   131125_urchinUrchin 32           8
#   140110spurp_t8hr_ 4              7
#   131204_urchinurchin 28           7
#   131204_eleganselegans 57         7
#   140110spurp_t8hr_ 2              7
#   ...
#   ciona_t0_10                           1
#   ciona_t0_11                           1
#   ciona_t0_16                           1
#   ciona_t0_14                           1
#   131106batstar_35hpf 12 top            1
#   urechis_t30m_40x_7                    1
#   131106batstar_unf 43                  1
#   20x Slide 11_w1Confocal Rho_s5.STK    1
#   ucaupo_25minUcaupo 21a (top)          1
#   urechis_t30m_40x_6                    1
#   urechis_t20min_3                      1
#   ucaupo210_Ucaupo 12 middle left       1
#   laevis_CSFlaevis 18/19                1
#   ucaupo_150minUcaupo 14 bottom         1
#   ucaupo_25minUcaupo 13                 1
#   Length: 1425, dtype: int64), (u'objective', 40x         1219
#   20x          209
#   60x          189
#   40x-zlsm     115
#   40x-olf       67
#   nan           66
#   20x-zlsm      42
#   63x           22
#   dtype: int64), (u'time_pf', nan     599
#   0       191
#   210     121
#   120      79
#   180      65
#   300      63
#   270      60
#   150      54
#   20       48
#   240      47
#   300      44
#   450      42
#   180      41
#   120      41
#   40       36
#   90       31
#   45       30
#   30       27
#   30       25
#   90       21
#   1200     20
#   25       20
#   380      18
#   390      17
#   60       16
#   260      16
#   85       15
#   50       15
#   20       15
#   210      14
#   330      13
#   150      12
#   140      12
#   420       9
#   720       9
#   450       8
#   510       8
#   270       7
#   260       6
#   130       5
#   390       3
#   65        2
#   135       2
#   46        1
#   75        1
#   dtype: int64), (u'num_of_cells', 1      691
#   2      239
#   4      232
#   8      190
#   32     148
#   16     139
#   64      76
#   64+     57
#   128     20
#   28      18
#   26      13
#   48      11
#   12       5
#   32+      3
#   dtype: int64), (u'meiotic', f    1456
#   t     473
#   dtype: int64), (u'stage', m      1094
#   a       414
#   mI      201
#   mII      96
#   aI       48
#   pI       47
#   aII      11
#   p         7
#   i         3
#   dtype: int64), (u'cell_diameter_um', 68.10804     3
#   81.18957     3
#   29.97918     3
#   72.15054     3
#   35.20000     3
#   44.00000     3
#   83.42103     2
#   105.41223    2
#   49.85211     2
#   113.64276    2
#   84.18102     2
#   69.85440     2
#   45.72876     2
#   22.26609     2
#   99.20000     2
#   ...
#   120.12464    1
#   13.13004     1
#   115.45600    1
#   177.61128    1
#   23.43033     1
#   197.27400    1
#   19.37166     1
#   10.30029     1
#   53.63589     1
#   132.33528    1
#   110.20000    1
#   256.76800    1
#   221.30000    1
#   37.16280     1
#   50.53125     1
#   Length: 1776, dtype: int64), (u'spindle_length__asters_um', 18.20000    5
#   25.48392    4
#   20.10000    4
#   30.77151    4
#   15.95979    4
#   45.30000    4
#   21.73248    4
#   25.70000    3
#   36.13995    3
#   14.48832    3
#   27.81240    3
#   37.78929    3
#   20.94015    3
#   23.78607    3
#   44.04708    3
#   ...
#   21.63546    1
#   26.06554    1
#   62.48088    1
#   39.82671    1
#   72.19905    1
#   18.93507    1
#   13.71216    1
#   3.08847     1
#   26.80000    1
#   23.36565    1
#   26.00136    1
#   43.49730    1
#   41.07180    1
#   22.99374    1
#   55.96437    1
#   Length: 1573, dtype: int64), (u'spindle_length_poles_um', 21.71631    6
#   22.40000    4
#   20.60058    4
#   16.00000    4
#   21.47376    4
#   17.56062    4
#   25.56477    4
#   12.64494    4
#   29.31621    4
#   22.62183    4
#   22.36311    3
#   17.88402    3
#   21.50610    3
#   3.76761     3
#   23.36565    3
#   ...
#   29.97918    1
#   22.60000    1
#   19.45251    1
#   5.90205     1
#   37.30419    1
#   16.40000    1
#   20.79462    1
#   18.65784    1
#   25.70000    1
#   28.57809    1
#   32.10000    1
#   26.10000    1
#   36.15612    1
#   24.70776    1
#   38.50000    1
#   Length: 1502, dtype: int64), (u'spindle_width_um', 6.14460     7
#   6.59736     7
#   8.80000     6
#   9.54030     6
#   7.30884     6
#   10.20000    6
#   12.12750    5
#   9.90000     5
#   7.87479     5
#   9.92838     5
#   9.70000     5
#   9.05520     5
#   18.40000    5
#   9.34626     5
#   9.50000     5
#   ...
#   9.20000     1
#   15.94362    1
#   12.10000    1
#   7.84920     1
#   10.30409    1
#   0.43659     1
#   7.93858     1
#   8.79648     1
#   22.70268    1
#   15.34533    1
#   17.25339    1
#   11.88495    1
#   16.26702    1
#   3.92931     1
#   15.50000    1
#   Length: 1207, dtype: int64), (u'spindle_aspect_ratio_asters_um',
#   1.500000    4
#   2.289062    2
#   1.600000    2
#   2.597403    2
#   2.903084    2
#   2.500000    2
#   1.500000    2
#   1.529915    2
#   2.684211    1
#   2.977883    1
#   8.020339    1
#   1.936652    1
#   2.960912    1
#   4.966667    1
#   1.508901    1
#   ...
#   4.613158    1
#   1.953003    1
#   2.252632    1
#   5.129983    1
#   2.714674    1
#   1.971014    1
#   1.038288    1
#   1.728693    1
#   2.017094    1
#   2.308163    1
#   2.193182    1
#   5.196429    1
#   4.134557    1
#   2.212711    1
#   2.687500    1
#   Length: 1826, dtype: int64), (u'spindle_aspect_ratio_poles_um', 1.500000    5
#   3.972603    2
#   1.500000    2
#   2.700000    2
#   2.294737    2
#   1.739130    2
#   1.166667    2
#   1.547619    2
#   1.464286    2
#   1.226471    2
#   1.900000    2
#   1.594059    2
#   1.543828    2
#   2.603448    2
#   1.787500    2
#   ...
#   2.508475    1
#   0.628743    1
#   1.432234    1
#   2.077922    1
#   1.021277    1
#   3.429185    1
#   3.158708    1
#   2.315789    1
#   5.040268    1
#   1.178310    1
#   3.196581    1
#   2.698231    1
#   2.110000    1
#   2.374456    1
#   2.437500    1
#   Length: 1813, dtype: int64), (u'astere-to-pole_distance_1_um',
#   0.00000    1168
#   1.29360      12
#   1.97274      11
#   2.10210       9
#   1.51998       9
#   2.74890       9
#   1.61700       8
#   2.45784       8
#   2.84592       8
#   2.16678       7
#   1.94040       7
#   2.52252       7
#   2.55486       6
#   2.61954       6
#   2.03742       5
#   ...
#   1.94560    1
#   4.57611    1
#   1.06722    1
#   5.81734    1
#   5.68878    1
#   1.26126    1
#   0.66960    1
#   4.96640    1
#   0.22638    1
#   3.53280    1
#   6.79140    1
#   7.32792    1
#   3.54123    1
#   3.44421    1
#   6.17694    1
#   Length: 367, dtype: int64), (u'aster-to-pole_distance_2_um', 0.00000    1227
#   1.94040       9
#   2.45784       8
#   1.51998       7
#   1.29360       7
#   2.61954       7
#   2.65188       6
#   1.13190       6
#   1.97274       6
#   0.80850       6
#   2.95911       5
#   2.42550       5
#   3.13698       5
#   2.19912       5
#   1.79487       5
#   ...
#   0.87156     1
#   8.61352     1
#   13.72378    1
#   0.97020     1
#   0.64680     1
#   1.07880     1
#   3.36336     1
#   4.91568     1
#   3.05613     1
#   13.90000    1
#   1.66551     1
#   6.24640     1
#   3.42804     1
#   4.57611     1
#   3.94548     1
#   Length: 345, dtype: int64), (u'inner_aster_diameter_1_um', 0.00000    127
#   1.89189     15
#   2.03742     14
#   3.00762     14
#   2.65188     12
#   2.10210     12
#   1.71402     12
#   2.60337     11
#   4.62462     11
#   2.19912     10
#   2.70039     10
#   3.05613     10
#   5.41695      9
#   2.24763      9
#   5.28759      9
#   ...
#   16.68066    1
#   1.58080     1
#   1.99950     1
#   2.62260     1
#   1.48764     1
#   3.62612     1
#   5.47840     1
#   2.86216     1
#   3.33560     1
#   11.88495    1
#   8.13351     1
#   6.01710     1
#   13.48578    1
#   15.31533    1
#   5.04504     1
#   Length: 816, dtype: int64), (u'inner_aster_diameter_2_um', 0.00000    137
#   1.89189     12
#   2.19912     11
#   2.34465     11
#   1.71402     11
#   1.84338     11
#   2.65188     10
#   3.83229      9
#   1.37445      9
#   2.70039      9
#   7.03395      9
#   3.96165      8
#   5.28759      8
#   2.81358      8
#   2.45784      7
#   ...
#   18.53082    1
#   14.84800    1
#   2.14124     1
#   14.79555    1
#   1.82280     1
#   13.90000    1
#   2.82720     1
#   10.18838    1
#   12.67728    1
#   5.98920     1
#   16.12800    1
#   14.74560    1
#   9.67680     1
#   16.88148    1
#   47.50000    1
#   Length: 798, dtype: int64), (u'outer_aster_diameter_1_um', 0.00000     119
#   25.01499      5
#   40.37649      5
#   32.95446      4
#   20.32569      4
#   22.73502      4
#   27.29496      4
#   29.54259      4
#   21.45759      4
#   25.98519      4
#   9.29775       3
#   39.37395      3
#   34.21572      3
#   59.60000      3
#   11.94963      3
#   ...
#   12.23412     1
#   13.60000     1
#   81.47490     1
#   102.10878    1
#   25.35846     1
#   31.12725     1
#   5.08710      1
#   28.72770     1
#   51.64698     1
#   24.59457     1
#   23.36565     1
#   18.82320     1
#   27.16560     1
#   31.48299     1
#   39.22842     1
#   Length: 1263, dtype: int64), (u'outer__diameter_2_um', 0.00000     130
#   48.31596      5
#   47.31342      4
#   39.21225      4
#   29.86599      4
#   26.63199      4
#   20.32569      4
#   24.54606      4
#   29.68812      4
#   24.67542      3
#   19.33932      3
#   34.23189      3
#   13.53429      3
#   51.51762      3
#   46.87683      3
#   ...
#   54.33120     1
#   51.87336     1
#   35.02422     1
#   45.90000     1
#   15.79809     1
#   64.42128     1
#   17.70615     1
#   21.76482     1
#   24.59457     1
#   23.36565     1
#   22.13673     1
#   13.71216     1
#   26.19540     1
#   24.96648     1
#   145.50000    1
#   Length: 1214, dtype: int64), (u'centrosome', t      1789
#   f       122
#   nan      18
#   dtype: int64), (u'metaphase_plate_lengt_h_um', 12.15984    7
#   9.05520     7
#   11.31900    7
#   7.43820     6
#   12.41856    6
#   10.89858    6
#   9.18456     6
#   10.73688    6
#   9.92838     6
#   11.30283    6
#   10.20327    5
#   7.76160     5
#   13.00000    5
#   9.50000     5
#   11.43219    5
#   ...
#   1.70342     1
#   3.42804     1
#   5.41695     1
#   6.69600     1
#   17.96487    1
#   11.01177    1
#   5.17440     1
#   19.28400    1
#   9.32892     1
#   19.90000    1
#   7.69692     1
#   18.22359    1
#   7.84216     1
#   17.80556    1
#   13.98090    1
#   Length: 993, dtype: int64), (u'metaphase_plate_width_um', 3.89697    9
#   5.06121    8
#   2.74890    8
#   4.13952    8
#   4.30122    8
#   3.10000    7
#   3.00762    7
#   3.78378    7
#   4.98036    7
#   2.60337    7
#   1.61700    7
#   5.17440    7
#   4.36590    7
#   4.00000    7
#   3.30000    7
#   ...
#   1.00254    1
#   6.22545    1
#   1.63317    1
#   2.52252    1
#   4.21034    1
#   5.75652    1
#   6.10000    1
#   3.62208    1
#   5.93920    1
#   2.23146    1
#   7.57760    1
#   3.99360    1
#   3.11758    1
#   3.63182    1
#   8.39680    1
#   Length: 589, dtype: int64), (u'metaphase_plate_aspect_ratio_um',
#   4.000000    4
#   3.000000    3
#   3.200000    2
#   2.400000    2
#   2.842105    2
#   3.015152    2
#   2.631579    2
#   2.684932    2
#   2.800000    2
#   2.444444    2
#   1.893939    2
#   3.210526    2
#   3.636364    2
#   2.000000    2
#   1.018182    2
#   ...
#   4.381643    1
#   3.577465    1
#   2.635452    1
#   3.600000    1
#   3.264463    1
#   2.621212    1
#   4.869565    1
#   0.940341    1
#   3.288235    1
#   3.064516    1
#   6.921053    1
#   2.449580    1
#   4.315789    1
#   1.844106    1
#   3.539062    1
#   Length: 1179, dtype: int64), (u'polar_body_diameter_1_um', 6.90459     4
#   7.76160     3
#   9.50000     3
#   6.07992     3
#   6.11226     3
#   5.44929     3
#   6.27396     3
#   4.68930     2
#   2.23200     2
#   7.00000     2
#   4.34973     2
#   11.76324    2
#   6.04758     2
#   8.21436     2
#   7.90000     2
#   ...
#   9.00669     1
#   9.05520     1
#   7.70000     1
#   6.80000     1
#   12.21320    1
#   6.40332     1
#   33.26670    1
#   12.92028    1
#   11.60000    1
#   1.93440     1
#   1.29360     1
#   5.75652     1
#   2.14830     1
#   8.95276     1
#   3.71910     1
#   Length: 169, dtype: int64), (u'polar_body_diameter_2_um', 8.66712     2
#   5.95056     2
#   4.78632     2
#   6.04758     2
#   5.28759     1
#   7.92330     1
#   7.40000     1
#   5.64333     1
#   10.36497    1
#   5.98920     1
#   5.06121     1
#   7.85862     1
#   8.27904     1
#   5.09355     1
#   7.89096     1
#   ...
#   5.57865     1
#   7.93947     1
#   6.71055     1
#   6.40332     1
#   1.93440     1
#   8.81265     1
#   14.10024    1
#   6.43566     1
#   6.10000     1
#   7.69692     1
#   10.78539    1
#   2.61954     1
#   1.55310     1
#   7.98798     1
#   2.50000     1
#   Length: 63, dtype: int64), (u'distance_between_chromosomes_um',
#   0.00000     1363
#   3.79995        3
#   10.04157       2
#   9.73434        2
#   16.57425       2
#   7.00161        2
#   6.38715        2
#   8.87733        2
#   21.48993       2
#   10.89858       2
#   14.97342       2
#   11.80000       2
#   9.83136        2
#   12.62877       2
#   8.90000        2
#   ...
#   14.70000    1
#   11.99814    1
#   9.78285     1
#   3.21783     1
#   34.65231    1
#   44.96877    1
#   7.09084     1
#   8.06883     1
#   12.90000    1
#   4.22037     1
#   14.80000    1
#   34.28040    1
#   26.71284    1
#   14.58534    1
#   44.75856    1
#   Length: 416, dtype: int64), (u'microscope', mm40      1196
#   mm60       143
#   zlsm40     130
#   mm20       115
#   zax20       94
#   olf         67
#   nsd60       50
#   zlsm20      27
#   mm45         1
#   mm44         1
#   mm47         1
#   mm46         1
#   mm41         1
#   mm43         1
#   mm42         1
#   zlsm25       1
#   mm48         1
#   nsd73        1
#   zlsm24       1
#   zlsm27       1
#   zlsm26       1
#   zlsm21       1
#   zlsm23       1
#   zlsm22       1
#   zlsm29       1
#   nsd78        1
#   nsd70        1
#   nsd72        1
#   nsd71        1
#   nsd69        1
#   nsd68        1
#   nsd63        1
#   nsd62        1
#   nsd61        1
#   nsd67        1
#   nsd66        1
#   nsd65        1
#   nsd64        1
#   zlsm34       1
#   zlsm35       1
#   zlsm32       1
#   zlsm33       1
#   zlsm30       1
#   zlsm31       1
#   nsd74        1
#   nsd75        1
#   nsd76        1
#   nsd77        1
#   zlsm28       1
#   dtype: int64), (u'fixation', df    909
#   m     757
#   pf    197
#   dtype: int64), (u'organism', urechis caupo                    508
#   Strongylocentrotus purpuratus    427
#   asterina miniata                 284
#   xenopus laevis                   164
#   caenorhabditis elegans           125
#   ciona intestinalis               117
#   helobdella robusta                94
#   cerebratulus marginatus           67
#   mytilus californianus             64
#   xenopus tropicalis                13
#   mus musculus                      13
#   Homo sapiens                      12
#   Equus caballus                     9
#   danio rerio                        9
#   drosophila melanogaster            7
#   sus scrofa                         4
#   Clytia hemisphaerica_1             4
#   monodelphis domestica              3
#   Callithrix jacchus                 3
#   Macaca mulatta                     2
#   dtype: int64), (u'phylum', echinodermata    700
#   annelida         602
#   chordata         349
#   nematoda         125
#   nemertea          67
#   mollusca          64
#   arthropoda         7
#   Cnidaria           4
#   dtype: int64), (u'classification', bd     1060
#   bpl     733
#   bpe     132
#   r         4
#   dtype: int64), (u'genome', 814     427
#   811     284
#   3100    164
#   100     125
#   115     117
#   230      94
#   1437     13
#   3481     13
#   3381     12
#   1505      9
#   2474      9
#   168       7
#   3024      4
#   2759      3
#   3501      3
#   3097      2
#   dtype: int64), (u'chromosomes', 18    605
#   36    452
#   42    429
#   28    181
#   12    125
#   32     67
#   46     15
#   40     13
#   20     13
#   64      9
#   50      9
#   8       7
#   dtype: int64), (u'day', 2014-06-03    590
#   2013-12-04    159
#   2013-05-23    143
#   2012-11-02    119
#   2013-11-25    115
#   2014-03-24    107
#   2014-01-10    104
#   NaT            66
#   2013-11-18     63
#   2014-02-06     55
#   2014-04-25     54
#   2014-06-17     52
#   2013-11-21     51
#   2010-04-23     49
#   2013-11-06     34
#   2013-11-22     32
#   2014-04-22     22
#   2014-07-18     20
#   2010-05-22     18
#   2014-04-04     17
#   2014-06-04     17
#   2014-01-27     11
#   2014-03-07      9
#   2014-02-28      7
#   2014-03-17      6
#   2013-11-12      6
#   2014-03-12      1
#   2014-03-21      1
#   2014-01-24      1
#   dtype: int64), (u'cleavage_type', s      666
#   rah    544
#   ra     284
#   dra    177
#   ro     171
#   sp      67
#   dm       9
#   sf       7
#   dtype: int64)]

# %%
df2.organism = df2.organism.str.replace(' ','_')

# %%
names=list(df2.organism.unique())

# %%
names=[str(name) for name in names]

# %%
names.sort()

# %%
names
# Out:
# ['Callithrix_jacchus',
#  'Clytia_hemisphaerica_1',
#  'Equus_caballus',
#  'Homo_sapiens',
#  'Macaca_mulatta',
#  'Strongylocentrotus_purpuratus',
#  'asterina_miniata',
#  'caenorhabditis_elegans',
#  'cerebratulus_marginatus',
#  'ciona_intestinalis',
#  'danio_rerio',
#  'drosophila_melanogaster',
#  'helobdella_robusta',
#  'monodelphis_domestica',
#  'mus_musculus',
#  'mytilus_californianus',
#  'sus_scrofa',
#  'urechis_caupo',
#  'xenopus_laevis',
#  'xenopus_tropicalis']

# %%
mics=list(df2.microscope.unique())

# %%
mics.sort()

# %%
mics
# Out:
# [nan,
#  u'mm20',
#  u'mm40',
#  u'mm41',
#  u'mm42',
#  u'mm43',
#  u'mm44',
#  u'mm45',
#  u'mm46',
#  u'mm47',
#  u'mm48',
#  u'mm60',
#  u'nsd60',
#  u'nsd61',
#  u'nsd62',
#  u'nsd63',
#  u'nsd64',
#  u'nsd65',
#  u'nsd66',
#  u'nsd67',
#  u'nsd68',
#  u'nsd69',
#  u'nsd70',
#  u'nsd71',
#  u'nsd72',
#  u'nsd73',
#  u'nsd74',
#  u'nsd75',
#  u'nsd76',
#  u'nsd77',
#  u'nsd78',
#  u'olf',
#  u'zax20',
#  u'zlsm20',
#  u'zlsm21',
#  u'zlsm22',
#  u'zlsm23',
#  u'zlsm24',
#  u'zlsm25',
#  u'zlsm26',
#  u'zlsm27',
#  u'zlsm28',
#  u'zlsm29',
#  u'zlsm30',
#  u'zlsm31',
#  u'zlsm32',
#  u'zlsm33',
#  u'zlsm34',
#  u'zlsm35',
#  u'zlsm40']

# %%
df2.image = df2.image.str.replace(' ','_')
df2.image = df2.image.str.replace('.','_')

# %%
df2.image
# Out:
# 0             131106batstar_35hpf_5
# 1             131106batstar_35hpf_6
# 2             131106batstar_35hpf_7
# 3            131106batstar_35hpf_10
# 4            131106batstar_35hpf_11
# 5        131106batstar_35hpf_12_top
# 6     131106batstar_35hpf_12_bottom
# 7            131106batstar_35hpf_15
# 8            131106batstar_35hpf_19
# 9            131106batstar_35hpf_23
# 10       131106batstar_35hpf_28_top
# 11    131106batstar_35hpf_28_bottom
# 12           131106batstar_35hpf_30
# 13       131106batstar_35hpf_32_top
# 14    131106batstar_35hpf_32_bottom
# ...
# 1914     20x_Slide_5_I_w2Confocal_DAPI_s1_STK
# 1915     20x_Slide_5_I_w2Confocal_DAPI_s2_STK
# 1916     20x_Slide_5_I_w2Confocal_DAPI_s5_STK
# 1917     20x_Slide_5_I_w2Confocal_DAPI_s7_STK
# 1918    20x_Slide_5_I_w2Confocal_DAPI_s11_STK
# 1919    20x_Slide_5_I_w2Confocal_DAPI_s14_STK
# 1920    20x_Slide_5_I_w2Confocal_DAPI_s15_STK
# 1921    20x_Slide_5_I_w2Confocal_DAPI_s16_STK
# 1922    20x_Slide_5_I_w2Confocal_DAPI_s17_STK
# 1923    20x_Slide_5_I_w2Confocal_DAPI_s20_STK
# 1924      20x_Slide_4_I_w1Confocal_Rho_s1_STK
# 1925      20x_Slide_4_I_w1Confocal_Rho_s4_STK
# 1926      20x_Slide_3_I_w1Confocal_Rho_s1_STK
# 1927      20x_Slide_3_I_w1Confocal_Rho_s3_STK
# 1928      20x_Slide_3_I_w1Confocal_Rho_s7_STK
# Name: image, Length: 1929, dtype: object

# %%
df2.image.value_counts()
# Out:
# 131121_urchinUrchin_2hrPF_6     18
# 131121_urchinUrchin_2hrPF_3     15
# mus_musculus3                   13
# 131125_urchinUrchin_27          12
# 131125_urchinUrchin_26          11
# spurp_t420mPF                    9
# 131121_urchinUrchin_2hrPF_4      9
# 131118_eleganselegans_35         8
# spurp_t90m_15_w1Confocal_561     8
# spurp_t90m_9_w1Confocal_561      8
# 131125_urchinUrchin_32           8
# 140110spurp_t8hr__2              7
# 140110spurp_t8hr__4              7
# 131204_urchinurchin_28           7
# spurp_t90m_13_w1Confocal_561     7
# ...
# 140110spurp_t2hr__8            1
# ucaupo_150minUcaupo_13_left    1
# Homo_sapiens5                  1
# urechis_t260m_40x_2            1
# 140110spurp_t2hr__3            1
# urechis_t210m_40x_55           1
# urechis_t210m_40x_12           1
# ucaupo210_UCauop_5_top_rght    1
# 140110spurp_t2hr__7            1
# 140110spurp_t2hr__6            1
# 140110spurp_t2hr__5            1
# 140110spurp_t2hr__4            1
# stg19stg19_21                  1
# urechis_t30m_40x_2             1
# urechis_t20m_40x_17            1
# Length: 1425, dtype: int64

# %% [markdown]
# Data seems to be clean and uniform. No noticeable dupes. Convert binary categoricals to binaries. Hold off with the rest.

# %% [markdown]
# **Potentially irrelevant variables**: image, objective, microscope, (maybe) fixation, (maybe) day and date.
# **Potentially redundant variables**: time_pf and stage, organism and phylum and classification (this is a tree), day and date.
#
# **Continuous variables (19)**:
# cell diameter, spindle_length\__asters_um, spindle_length_poles_um, spindle_width_um, spindle_aspect_ratio_asters_um, spindle_aspect_ratio_poles_um, astere-to-pole_distance_1_um, aster-to-pole_distance_2_um, inner_aster_diameter_1_um, inner_aster_diameter_2_um, outer_aster_diameter_1_um, outer__diameter_2_um, 'metaphase_plate_lengt_h_um, metaphase_plate_width_um, metaphase_plate_aspect_ratio_um, polar_body_diameter_1_um, polar_body_diameter_2_um, distance_between_chromosomes_um, (maybe) genome
# **Categorical variables (11)**: time_pf, meiotic (BIN), stage, centrosome (BIN), organism, phylum, classification, cleavage_type, *objective, microscope,fixation, image*
# **Count variables (2)**: num_of_cells, chromosomes
# **Time/categorical variables (2)**: *date, day*

# %% [markdown]
# ####Binarize

# %%
df2.columns
# Out:
# Index([u'date', u'image', u'objective', u'time_pf', u'num_of_cells', u'meiotic', u'stage', u'cell_diameter_um', u'spindle_length__asters_um', u'spindle_length_poles_um', u'spindle_width_um', u'spindle_aspect_ratio_asters_um', u'spindle_aspect_ratio_poles_um', u'astere-to-pole_distance_1_um', u'aster-to-pole_distance_2_um', u'inner_aster_diameter_1_um', u'inner_aster_diameter_2_um', u'outer_aster_diameter_1_um', u'outer__diameter_2_um', u'centrosome', u'metaphase_plate_lengt_h_um', u'metaphase_plate_width_um', u'metaphase_plate_aspect_ratio_um', u'polar_body_diameter_1_um', u'polar_body_diameter_2_um', u'distance_between_chromosomes_um', u'microscope', u'fixation', u'organism', u'phylum', u'classification', u'genome', u'chromosomes', u'day', u'cleavage_type'], dtype='object')

# %%
df2.meiotic.value_counts()
df2.meiotic.replace({'t':1,'f':0},inplace=True)

# %%
df2.meiotic.value_counts()
# Out:
# 0    1456
# 1     473
# dtype: int64

# %%
df2.centrosome.value_counts()
df2.centrosome.replace({'t':1,'f':0},inplace=True)
df2.centrosome.value_counts()
# Out:
# 1      1789
# 0       122
# nan      18
# dtype: int64

# %%
df2.head()
# Out:
#         date                   image objective time_pf num_of_cells  meiotic  \
# 0 2013-11-06   131106batstar_35hpf_5       40x    210             1        0
# 1 2013-11-06   131106batstar_35hpf_6       40x    210             1        0
# 2 2013-11-06   131106batstar_35hpf_7       40x    210             1        0
# 3 2013-11-06  131106batstar_35hpf_10       40x    210             1        0
# 4 2013-11-06  131106batstar_35hpf_11       40x    210             1        0
#
#   stage  cell_diameter_um  spindle_length__asters_um  spindle_length_poles_um  \
# 0     a         177.82149                   41.37903                 26.13072
# 1     m         163.05828                   24.85329                 18.28827
# 2     p         206.00580                   35.08890                 27.24645
# 3     m         194.04000                   42.39774                 42.39774
# 4   NaN         180.36018                        NaN                      NaN
#
#             ...             distance_between_chromosomes_um  microscope  \
# 0           ...                                    10.55901        mm40
# 1           ...                                     0.00000        mm40
# 2           ...                                         NaN        mm40
# 3           ...                                     0.00000        mm40
# 4           ...                                         NaN        mm40
#
#    fixation          organism         phylum  classification  genome  \
# 0        pf  asterina_miniata  echinodermata              bd     811
# 1        pf  asterina_miniata  echinodermata              bd     811
# 2        pf  asterina_miniata  echinodermata              bd     811
# 3        pf  asterina_miniata  echinodermata              bd     811
# 4        pf  asterina_miniata  echinodermata              bd     811
#
#    chromosomes        day cleavage_type
# 0           36 2013-11-06            ra
# 1           36 2013-11-06            ra
# 2           36 2013-11-06            ra
# 3           36 2013-11-06            ra
# 4           36 2013-11-06            ra
#
# [5 rows x 35 columns]

# %%
df3 = df2.copy()

# %% [markdown]
# Try dropping the potentially irrelevant variables. Use them later ofr sanity check. Dropping:  image, objective, microscope, (maybe) fixation, (maybe) day and date.

# %%
df3=df3.drop(['image', 'objective', 'microscope','fixation', 'day' , 'date'], axis=1)

# %%
df3.head(1)
# Out:
#   time_pf num_of_cells  meiotic stage  cell_diameter_um  \
# 0    210             1        0     a         177.82149
#
#    spindle_length__asters_um  spindle_length_poles_um  spindle_width_um  \
# 0                   41.37903                 26.13072          14.45598
#
#    spindle_aspect_ratio_asters_um  spindle_aspect_ratio_poles_um  \
# 0                        2.862416                       1.807606
#
#                ...                metaphase_plate_aspect_ratio_um  \
# 0              ...                                            NaN
#
#    polar_body_diameter_1_um  polar_body_diameter_2_um  \
# 0                       NaN                       NaN
#
#    distance_between_chromosomes_um          organism         phylum  \
# 0                         10.55901  asterina_miniata  echinodermata
#
#   classification  genome  chromosomes  cleavage_type
# 0             bd     811           36             ra
#
# [1 rows x 29 columns]

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scat = scatter_matrix(df3, figsize = (14,14), diagonal = 'kde')

# %%
scat = scatter_matrix(df3, figsize = (20,20), diagonal = 'kde')

# %%
scat

# %%
#STEP3: Fill in the missing data with the random sampling & SVD. Check ou the NNMF. Do it with DF3 or later.

# %%
#http://www.secnetix.de/olli/Python/lambda_functions.hawk
